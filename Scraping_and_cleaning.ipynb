# %% [markdown]
# <a href="https://colab.research.google.com/github/snjvnyk/Professor-Reviews/blob/main/Scraping_and_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the webpage you want to scrape
url = "https://www.ratemyprofessors.com/professor/742919"
response = requests.get(url)

# %%
# Parse the HTML content of the webpage
soup = BeautifulSoup(response.content, "html.parser")

# %%
comment_divs = soup.find_all('div', {'class':['Comments__StyledComments-dzzyvm-0 gRjWel', 'MetaItem__StyledMetaItem-y0ixml-0 LXClX', 'TimeStamp__StyledTimeStamp-sc-9q2r30-0 bXQmMr RatingHeader__RatingTimeStamp-sc-1dlkqw1-4 iwwYJD']} )
line=[]
for i, div in enumerate(comment_divs, start=1):
    comment_text = div.get_text(strip=True)
    #print(f"Line {i}: {comment_text}")
    if ', 20' in comment_text:
      line.append(i)

# %%
#def remove_eve_elements(lst):
line_even=line[:]
i=0
for element in line:
        if i % 2 == 0:
            i = i + 1
            pass

        else:
            line_even.remove(element)
            i = i + 1

# %%
#def remove_eve_elements(lst):
line_odd=line[:]
i=0
for element in line:
        if i % 2 == 0:
            line_odd.remove(element)
            i = i + 1
        else:
            i = i + 1
            pass

# %%
#for i in range(len(line_odd)):
#  print(line_odd[i], line_even[i])

# %%
print(line_odd)
print(line_even)
# Out:
# [2, 9, 17, 24, 33, 41, 48, 55, 62, 70, 78, 86, 94, 102, 109, 115, 123, 131, 139, 147]
# [1, 8, 16, 23, 32, 40, 47, 54, 61, 69, 77, 85, 93, 101, 108, 114, 122, 130, 138, 146]

# %%
import pandas as pd
import numpy as np
index = [i for i in range(len(line))]
df = pd.DataFrame(np.nan, index,columns=['Date', 'Review', 'For Credit', 'Attendance', 'Grade', 'Textbook', 'Online Class', 'Would Take Again'])

# %%
print(df.shape)
df.head()
# Out:
# (40, 8)
#    Date  Review  For Credit  Attendance  Grade  Textbook  Online Class  \
# 0   NaN     NaN         NaN         NaN    NaN       NaN           NaN
# 1   NaN     NaN         NaN         NaN    NaN       NaN           NaN
# 2   NaN     NaN         NaN         NaN    NaN       NaN           NaN
# 3   NaN     NaN         NaN         NaN    NaN       NaN           NaN
# 4   NaN     NaN         NaN         NaN    NaN       NaN           NaN
#
#    Would Take Again
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
reviews=[]
comment_divs = soup.find_all('div', {'class':[ 'MetaItem__StyledMetaItem-y0ixml-0 LXClX', 'TimeStamp__StyledTimeStamp-sc-9q2r30-0 bXQmMr RatingHeader__RatingTimeStamp-sc-1dlkqw1-4 iwwYJD']} )
line=[]
for i, div in enumerate(comment_divs, start=1):
    comment_text = div.get_text(strip=True)
    reviews.append(comment_text)
#'Comments__StyledComments-dzzyvm-0 gRjWel',

# %%
index = 0
for review in reviews:
      if', 2' in review:
        index=index+1
        df['Date'][index]=review

      elif ':' in review:
        try:
          key, value = map(str.strip, review.split(':'))  # Limit split to 1 occurrence
          if key in df.keys():
            df[key][index] = value
        except:
            print(review)

#print(df)

# %%
reviews=[]
comment_divs = soup.find_all('div', {'class':[ 'Comments__StyledComments-dzzyvm-0 gRjWel', 'TimeStamp__StyledTimeStamp-sc-9q2r30-0 bXQmMr RatingHeader__RatingTimeStamp-sc-1dlkqw1-4 iwwYJD']} )
line=[]
for i, div in enumerate(comment_divs, start=1):
    comment_text = div.get_text(strip=True)
    reviews.append(comment_text)

# %%
index = 0
for review in reviews:
      if', 2' in review:
        index=index+1
        df['Date'][index]=review

      else:
        try:
            df[key][index] = value
        except:
            print(review)

#print(df)
# Out:
# <ipython-input-15-44228631e42a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'][index]=review
# <ipython-input-15-44228631e42a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[key][index] = value
# <ipython-input-15-44228631e42a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[key][index] = value

# %%
df
# Out:
#               Date                                             Review  \
# 0              NaN                                                NaN
# 1   Sep 12th, 2023                                                NaN
# 2   Sep 12th, 2023  He is a very tough grader. Toughest grader the...
# 3   Aug 18th, 2022                                                NaN
# 4   Aug 18th, 2022  To be fair, his lecture is clear, you can lear...
# 5   May 28th, 2022                                                NaN
# 6   May 28th, 2022  Avoid... this guy is only around because of te...
# 7   Aug 16th, 2021                                                NaN
# 8   Aug 16th, 2021  Just no. Truthfully an awful professor with th...
# 9    Aug 5th, 2021                                                NaN
# 10   Aug 5th, 2021  This is a very difficult class, but there are ...
# 11  May 31st, 2021                                                NaN
# ...

# %%
df_cleaned = df.dropna(how='all', subset=df.columns.difference(['Date']))
df_cleaned = df_cleaned.reset_index()
from google.colab import files
df_cleaned.to_csv('rmp_data.csv')
files.download('rmp_data.csv')

# %%
# ALL JUNK BELOW THIS

# %%
index = 0
for review in reviews:
      if', 2' in review:
        index=index+1
        df['Date'][index]=review

      elif ':' in review:
        try:
          key, value = map(str.strip, review.split(':'))  # Limit split to 1 occurrence
          if key in df.keys():
            df[key][index] = value
        except:
            print(review)

      else:
        df['Review'][index]=review


#print(df)
# Out:
# <ipython-input-16-798c76a86611>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'][index]=review
# <ipython-input-16-798c76a86611>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review'][index]=review

# %%
df_cleaned = df.dropna(how='all', subset=df.columns.difference(['Date']))

# %%
df.shape
# Out:
# (40, 8)

# %%
#comment_divs = soup.find_all('div', 'TimeStamp__StyledTimeStamp-sc-9q2r30-0 bXQmMr RatingHeader__RatingTimeStamp-sc-1dlkqw1-4 iwwYJD')

# %%
#comment_divs = soup.find_all('div', {'class':['Comments__StyledComments-dzzyvm-0 gRjWel', 'MetaItem__StyledMetaItem-y0ixml-0 LXClX', 'TimeStamp__StyledTimeStamp-sc-9q2r30-0 bXQmMr RatingHeader__RatingTimeStamp-sc-1dlkqw1-4 iwwYJD']} )

# %%
# Initialize empty lists for each column
dates = []
reviews_text = []
for_credit = []
attendance = []
grade = []
textbook = []
online_class = []
would_take_again = []
index = 0
k=0
for review in reviews:
    if k in line_odd:
      index=index+1
      k=k+1
      pass
    else:
      if ':' in comment_text:
        key, value = map(str.strip, comment_text.split(':', 1))  # Limit split to 1 occurrence
        if key=='For Credit':
          df[index]['For Credit']=value
        if key=='Attendance':
          df[index]['For Credit']=value
        if key=='Grade':
          df[index]['For Credit']=value
        if key=='Textbook':
          df[index]['For Credit']=value
        if key=='Online lass':
          df[index]['For Credit']=value
        if key=='Textbook':
          df[index]['For Credit']=value

      else:
        df[index][review]=review

    if "For Credit:" in reviews
    for_credit_text = "For Credit:"
    attendance_text = "Attendance:"
    grade_text = "Grade:"
    textbook_text = "Textbook:"
    online_class_text = "Online Class:"
    would_take_again_text = "Would Take Again:"

    # Find the positions of each keyword in the review text
    for_credit_pos = review_text.contains(for_credit_text)
    attendance_pos = review_text.find(attendance_text)
    grade_pos = review_text.find(grade_text)
    textbook_pos = review_text.find(textbook_text)
    online_class_pos = review_text.find(online_class_text)
    would_take_again_pos = review_text.find(would_take_again_text)

    # Extract the values based on keyword positions
    for_credit_value = review_text[for_credit_pos + len(for_credit_text):attendance_pos].strip() if for_credit_pos != -1 else None
    attendance_value = review_text[attendance_pos + len(attendance_text):grade_pos].strip() if attendance_pos != -1 else None
    grade_value = review_text[grade_pos + len(grade_text):textbook_pos].strip() if grade_pos != -1 else None
    textbook_value = review_text[textbook_pos + len(textbook_text):online_class_pos].strip() if textbook_pos != -1 else None
    online_class_value = review_text[online_class_pos + len(online_class_text):would_take_again_pos].strip() if online_class_pos != -1 else None
    would_take_again_value = review_text[would_take_again_pos + len(would_take_again_text):].strip() if would_take_again_pos != -1 else None

    # Append the extracted values to their respective lists
    dates.append(date)
    reviews_text.append(review_text)
    for_credit.append(for_credit_value)
    attendance.append(attendance_value)
    grade.append(grade_value)
    textbook.append(textbook_value)
    online_class.append(online_class_value)
    would_take_again.append(would_take_again_value)

# Create a DataFrame
data = {
    'Date': dates,
    'Review': reviews_text,
    'For Credit': for_credit,
    'Attendance': attendance,
    'Grade': grade,
    'Textbook': textbook,
    'Online Class': online_class,
    'Would Take Again': would_take_again
}

df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
reviews
# Out:
# ['Sep 12th, 2023',
#  'Sep 12th, 2023',
#  'For Credit:Yes',
#  'Attendance:Mandatory',
#  'Grade:Rather not say',
#  'Textbook:Yes',
#  "He is a very tough grader. Toughest grader the department has. The class isn't supposed to be as hard as it is, but he makes it so. Very approachable and will go out of his way to explain things to you. Nevertheless, he structures the class so you have to allocate every minute of your time to it. Go to TA sessions, attend workshops, and pass.",
#  'Aug 18th, 2022',
#  'Aug 18th, 2022',
#  'For Credit:Yes',
#  'Attendance:Mandatory',
#  'Grade:C+',
#  'Textbook:Yes',
#  'Online Class:Yes',
#  'To be fair, his lecture is clear, you can learn a lot from him. On the other hand, he will ruin your GPA. The time he gave for exam is so intense, and the difficulties of questions is much harder than any other courses I took at SJSU. He never curve, and exam average is like 30 or less out of 100 most times. took this class in summer if you can.',
# ...

# %%
index = 0
for review in reviews:
      if', 2' in review:
        index=index+1
        df['Date'][index]=review

      elif ':' in review:
        try:
          key, value = map(str.strip, comment_text.split(':'))  # Limit split to 1 occurrence
          dfd.loc[mask, 'c'] = 42df[key][index] = value
        except:
          print(review)

      else:
        df['Review'][index]=review


#print(df)
# Out:
# For Credit:Yes
# Attendance:Mandatory
# Grade:Rather not say
# Textbook:Yes
# For Credit:Yes
# Attendance:Mandatory
# Grade:C+
# Textbook:Yes
# Online Class:Yes
# For Credit:Yes
# Attendance:Mandatory
# Grade:Not sure yet
# Textbook:N/A
# For Credit:Yes
# Attendance:Mandatory
# Would Take Again:No
# Grade:Rather not say
# Textbook:Yes
# Online Class:Yes
# For Credit:Yes
# Attendance:Mandatory
# Would Take Again:Yes
# Textbook:Yes
# Online Class:Yes
# For Credit:Yes
# Would Take Again:No
# Grade:C
# Textbook:No
# For Credit:Yes
# Would Take Again:No
# Grade:C
# Textbook:No
# For Credit:Yes
# Attendance:Mandatory
# Would Take Again:No
# Textbook:No
# For Credit:Yes
# Attendance:Mandatory
# Would Take Again:No
# Grade:Rather not say
# Textbook:No
# For Credit:Yes
# Attendance:Mandatory
# Would Take Again:No
# Grade:Not sure yet
# Textbook:Yes
# For Credit:Yes
# Attendance:Mandatory
# Would Take Again:No
# Grade:Not sure yet
# Textbook:Yes
# For Credit:Yes
# Attendance:Mandatory
# ...

# %%
for review in reviews:
      if ':' in review:
          key, value = map(str.strip, comment_text.split(':',1))  # Limit split to 1 occurrence
          print(key,value)
      else:
        print(review)
# Out:
# Sep 12th, 2023
# Sep 12th, 2023
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-190-0c6a2584f877> in <cell line: 1>()
#       1 for review in reviews:
#       2       if ':' in review:
# ----> 3           key, value = map(str.strip, comment_text.split(':',1))  # Limit split to 1 occurrence
#       4           print(key,value)
#       5       else:
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
index = 0
for review in reviews:
      if', 2' in review:
        index=index+1
        df['Date'][index]=review

      elif ':' in review:
        try:
          key, value = map(str.strip, review.split(':'))  # Limit split to 1 occurrence
          if key in df.keys():
            df[key][index] = value
        except:
            print(review)

      else:
        df['Review'][index]=review


#print(df)
# Out:
# <ipython-input-183-562b8d8e9bb4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[key][index] = value
# <ipython-input-183-562b8d8e9bb4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review'][index]=review

# %%
for review in reviews:
      if', 2' in review:
        index=index+1
        df['Date'][index]=review

      elif ':' in review:
        try:
          key, value = map(str.strip, comment_text.split(':'))  # Limit split to 1 occurrence
          if key in df.keys():
            df.loc[key,index] = value
# Out:
#   File "<ipython-input-192-b7ac3cda206d>", line 10
#     df.loc[key,index] = value
#                              ^
# SyntaxError: incomplete input

# %%
print(reviews)
# Out:
# ['Sep 12th, 2023', 'Sep 12th, 2023', 'For Credit:Yes', 'Attendance:Mandatory', 'Grade:Rather not say', 'Textbook:Yes', "He is a very tough grader. Toughest grader the department has. The class isn't supposed to be as hard as it is, but he makes it so. Very approachable and will go out of his way to explain things to you. Nevertheless, he structures the class so you have to allocate every minute of your time to it. Go to TA sessions, attend workshops, and pass.", 'Aug 18th, 2022', 'Aug 18th, 2022', 'For Credit:Yes', 'Attendance:Mandatory', 'Grade:C+', 'Textbook:Yes', 'Online Class:Yes', 'To be fair, his lecture is clear, you can learn a lot from him. On the other hand, he will ruin your GPA. The time he gave for exam is so intense, and the difficulties of questions is much harder than any other courses I took at SJSU. He never curve, and exam average is like 30 or less out of 100 most times. took this class in summer if you can.', 'May 28th, 2022', 'May 28th, 2022', 'For Credit:Yes', 
# ...

# %%
df.shape
# Out:
# (40, 101)

# %%
reviews_text = []
for_credit = []
attendance = []
grade = []
textbook = []
online_class = []
would_take_again = []

# %%
print(for_credit)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
comment_divs = soup.find_all('div', {'class':['Comments__StyledComments-dzzyvm-0 gRjWel', 'MetaItem__StyledMetaItem-y0ixml-0 LXClX', 'TimeStamp__StyledTimeStamp-sc-9q2r30-0 bXQmMr RatingHeader__RatingTimeStamp-sc-1dlkqw1-4 iwwYJD']} )
i=0
for j in range(4):
  for i, div in enumerate(comment_divs, start=(line_even[j])):
      print(j,line_even[j])
      if i==(line_even[j]):
        i=i+1
        pass
      elif i == line_even[j+1]:
        print('CUTTING THIS OFF',i,comment_text)
        i=i+1
        break
      else:
        comment_text = div.get_text(strip=True)
        print('passed line',i,comment_text)
        i=i+1
# Out:
# 0 1
# 0 1
# passed line 2 Sep 12th, 2023
# 0 1
# passed line 3 For Credit:Yes
# 0 1
# passed line 4 Attendance:Mandatory
# 0 1
# passed line 5 Grade:Rather not say
# 0 1
# passed line 6 Textbook:Yes
# 0 1
# passed line 7 He is a very tough grader. Toughest grader the department has. The class isn't supposed to be as hard as it is, but he makes it so. Very approachable and will go out of his way to explain things to you. Nevertheless, he structures the class so you have to allocate every minute of your time to it. Go to TA sessions, attend workshops, and pass.
# 0 1
# CUTTING THIS OFF 8 He is a very tough grader. Toughest grader the department has. The class isn't supposed to be as hard as it is, but he makes it so. Very approachable and will go out of his way to explain things to you. Nevertheless, he structures the class so you have to allocate every minute of your time to it. Go to TA sessions, attend workshops, and pass.
# 1 8
# 1 8
# passed line 9 Sep 12th, 2023
# 1 8
# ...
